# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
    torch.cuda.manual_seed(random_state)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device
# Out:
# device(type='cuda')

# %%
dataset_path = "data/Auto_MPG_data.csv"
dataset = pd.read_csv(dataset_path)
dataset.head()
# Out:
#     MPG  Cylinders  Displacement  Horsepower  Weight  Acceleration  \
# 0  18.0          8         307.0       130.0  3504.0          12.0
# 1  15.0          8         350.0       165.0  3693.0          11.5
# 2  18.0          8         318.0       150.0  3436.0          11.0
# 3  16.0          8         304.0       150.0  3433.0          12.0
# 4  17.0          8         302.0       140.0  3449.0          10.5
#
#    Model Year  Europe  Japan  USA
# 0          70       0      0    1
# 1          70       0      0    1
# 2          70       0      0    1
# 3          70       0      0    1
# 4          70       0      0    1

# %%
X = dataset.drop(columns="MPG").values
y = dataset["MPG"].values

# %%
val_size = 0.2
test_size = 0.125
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(
    X, y, test_size=val_size, random_state=random_state, shuffle=is_shuffle
)

X_train, X_test, y_train, y_test = train_test_split(
    X_train, y_train, test_size=test_size, random_state=random_state, shuffle=is_shuffle
)

# %%
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val = normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
class CustomDataset(Dataset):
    def __init__(self, X, y):
        self.X = X
        self.y = y

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]

# %%
batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %%
class MLP(nn.Module):
    def __init__(self, input_dims, hidden_dims, output_dims):
        super().__init__()
        self.linear1 = nn.Linear(input_dims, hidden_dims)
        self.linear2 = nn.Linear(hidden_dims, hidden_dims)
        self.output = nn.Linear(hidden_dims, output_dims)

    def forward(self, x):
        x = self.linear1(x)
        x = F.relu(x)
        x = self.linear2(x)
        x = F.relu(x)
        out = self.output(x)
        return out.squeeze(1)

# %%
input_dims = X_train.shape[1]
output_dims = 1
hidden_dims = 64

model = MLP(input_dims=input_dims, hidden_dims=hidden_dims, output_dims=output_dims).to(
    device
)
model
# Out:
# MLP(
#   (linear1): Linear(in_features=9, out_features=64, bias=True)
#   (linear2): Linear(in_features=64, out_features=64, bias=True)
#   (output): Linear(in_features=64, out_features=1, bias=True)
# )

# %%
lr = 1e-2
criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=lr)

# %%
def r_squared(y_true, y_pred):
    y_true = torch.Tensor(y_true).to(device)
    y_pred = torch.Tensor(y_pred).to(device)
    mean_true = torch.mean(y_true)
    ss_tot = torch.sum((y_true - mean_true) ** 2)
    ss_res = torch.sum((y_true - y_pred) ** 2)
    r2 = 1 - (ss_res / ss_tot)
    return r2

# %%
epochs = 100
train_losses = []
val_losses = []
train_r2 = []
val_r2 = []

for epoch in range(epochs):
    train_loss = 0.0
    train_target = []
    val_target = []
    train_predict = []
    val_predict = []
    model.train()
    for X_samples, y_samples in train_loader:
        X_samples = X_samples.to(device)
        y_samples = y_samples.to(device)
        optimizer.zero_grad()
        outputs = model(X_samples)
        train_predict += outputs.tolist()
        train_target += y_samples.tolist()
        loss = criterion(outputs, y_samples)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    train_loss /= len(train_loader)
    train_losses.append(train_loss)
    train_r2.append(r_squared(train_target, train_predict))
    model.eval()
    val_loss = 0.0
    with torch.no_grad():
        for X_samples, y_samples in val_loader:
            X_samples = X_samples.to(device)
            y_samples = y_samples.to(device)
            outputs = model(X_samples)
            val_predict += outputs.tolist()
            val_target += y_samples.tolist()
            loss = criterion(outputs, y_samples)
            val_loss += loss.item()
    val_loss /= len(val_loader)
    val_losses.append(val_loss)
    val_r2.append(r_squared(val_target, val_predict))
    print(
        f"\nEPOCH {epoch + 1}:\tTraining loss: {train_loss:.3f}\tValidation loss: {val_loss:.3f}"
    )
# Out:
# EPOCH 1:	Training loss: 282.770	Validation loss: 88.670
#
# EPOCH 2:	Training loss: 137.627	Validation loss: 72.291
#
# EPOCH 3:	Training loss: 71.299	Validation loss: 19.823
#
# EPOCH 4:	Training loss: 24.021	Validation loss: 156.088
#
# EPOCH 5:	Training loss: 99.607	Validation loss: 28.132
#
# EPOCH 6:	Training loss: 17.785	Validation loss: 6.569
#
# EPOCH 7:	Training loss: 15.954	Validation loss: 13.338
#
# EPOCH 8:	Training loss: 36.122	Validation loss: 32.011
#
# EPOCH 9:	Training loss: 16.440	Validation loss: 36.635
#
# EPOCH 10:	Training loss: 21.854	Validation loss: 47.800
#
# EPOCH 11:	Training loss: 30.077	Validation loss: 20.688
#
# EPOCH 12:	Training loss: 9.934	Validation loss: 5.671
#
# EPOCH 13:	Training loss: 16.008	Validation loss: 12.298
#
# EPOCH 14:	Training loss: 11.469	Validation loss: 12.618
#
# EPOCH 15:	Training loss: 14.523	Validation loss: 8.656
#
# EPOCH 16:	Training loss: 10.114	Validation loss: 19.112
#
# EPOCH 17:	Training loss: 12.141	Validation loss: 14.480
#
# EPOCH 18:	Training loss: 15.554	Validation loss: 12.385
#
# EPOCH 19:	Training loss: 14.683	Validation loss: 5.276
#
# EPOCH 20:	Training loss: 7.241	Validation loss: 5.164
#
# EPOCH 21:	Training loss: 8.790	Validation loss: 4.790
#
# EPOCH 22:	Training loss: 6.167	Validation loss: 5.578
#
# EPOCH 23:	Training loss: 9.994	Validation loss: 47.496
#
# EPOCH 24:	Training loss: 10.343	Validation loss: 16.933
#
# EPOCH 25:	Training loss: 9.331	Validation loss: 9.170
#
# EPOCH 26:	Training loss: 10.611	Validation loss: 6.634
#
# EPOCH 27:	Training loss: 6.227	Validation loss: 6.231
#
# EPOCH 28:	Training loss: 9.938	Validation loss: 5.186
#
# EPOCH 29:	Training loss: 6.543	Validation loss: 11.485
#
# EPOCH 30:	Training loss: 17.704	Validation loss: 4.662
#
# EPOCH 31:	Training loss: 7.853	Validation loss: 5.678
#
# EPOCH 32:	Training loss: 6.813	Validation loss: 5.914
#
# EPOCH 33:	Training loss: 7.059	Validation loss: 4.535
#
# EPOCH 34:	Training loss: 6.735	Validation loss: 6.311
#
# EPOCH 35:	Training loss: 7.654	Validation loss: 6.132
#
# EPOCH 36:	Training loss: 5.762	Validation loss: 7.085
#
# EPOCH 37:	Training loss: 6.753	Validation loss: 6.216
#
# EPOCH 38:	Training loss: 6.869	Validation loss: 9.575
#
# EPOCH 39:	Training loss: 7.170	Validation loss: 14.567
#
# EPOCH 40:	Training loss: 7.517	Validation loss: 5.600
#
# EPOCH 41:	Training loss: 5.795	Validation loss: 19.524
#
# EPOCH 42:	Training loss: 7.435	Validation loss: 5.445
#
# EPOCH 43:	Training loss: 7.207	Validation loss: 26.303
#
# EPOCH 44:	Training loss: 9.419	Validation loss: 10.936
#
# EPOCH 45:	Training loss: 6.437	Validation loss: 5.036
#
# EPOCH 46:	Training loss: 7.970	Validation loss: 6.459
#
# EPOCH 47:	Training loss: 6.207	Validation loss: 6.280
#
# EPOCH 48:	Training loss: 5.239	Validation loss: 6.796
#
# EPOCH 49:	Training loss: 6.584	Validation loss: 8.701
#
# EPOCH 50:	Training loss: 6.428	Validation loss: 11.017
#
# EPOCH 51:	Training loss: 7.598	Validation loss: 8.200
#
# EPOCH 52:	Training loss: 10.541	Validation loss: 5.139
#
# EPOCH 53:	Training loss: 7.169	Validation loss: 4.855
#
# EPOCH 54:	Training loss: 6.382	Validation loss: 5.348
#
# EPOCH 55:	Training loss: 5.352	Validation loss: 5.146
#
# EPOCH 56:	Training loss: 5.480	Validation loss: 6.196
#
# EPOCH 57:	Training loss: 7.216	Validation loss: 6.743
#
# EPOCH 58:	Training loss: 6.379	Validation loss: 15.606
#
# EPOCH 59:	Training loss: 6.937	Validation loss: 8.481
#
# EPOCH 60:	Training loss: 5.655	Validation loss: 4.920
#
# EPOCH 61:	Training loss: 5.314	Validation loss: 7.566
#
# EPOCH 62:	Training loss: 9.522	Validation loss: 4.643
#
# EPOCH 63:	Training loss: 6.219	Validation loss: 11.583
#
# EPOCH 64:	Training loss: 5.950	Validation loss: 5.865
#
# EPOCH 65:	Training loss: 8.049	Validation loss: 5.130
#
# EPOCH 66:	Training loss: 5.209	Validation loss: 5.191
#
# EPOCH 67:	Training loss: 5.727	Validation loss: 6.235
#
# EPOCH 68:	Training loss: 8.988	Validation loss: 6.709
#
# EPOCH 69:	Training loss: 6.564	Validation loss: 8.359
#
# EPOCH 70:	Training loss: 6.038	Validation loss: 5.535
#
# EPOCH 71:	Training loss: 5.127	Validation loss: 4.759
#
# EPOCH 72:	Training loss: 5.643	Validation loss: 8.631
#
# EPOCH 73:	Training loss: 6.310	Validation loss: 8.805
#
# EPOCH 74:	Training loss: 5.721	Validation loss: 5.076
#
# EPOCH 75:	Training loss: 5.524	Validation loss: 17.598
#
# EPOCH 76:	Training loss: 7.426	Validation loss: 15.625
#
# EPOCH 77:	Training loss: 9.966	Validation loss: 6.904
#
# EPOCH 78:	Training loss: 6.568	Validation loss: 5.262
#
# EPOCH 79:	Training loss: 5.647	Validation loss: 9.771
#
# EPOCH 80:	Training loss: 7.531	Validation loss: 5.732
#
# EPOCH 81:	Training loss: 9.611	Validation loss: 5.065
#
# EPOCH 82:	Training loss: 5.577	Validation loss: 5.663
#
# EPOCH 83:	Training loss: 5.521	Validation loss: 7.793
#
# EPOCH 84:	Training loss: 5.161	Validation loss: 5.087
#
# EPOCH 85:	Training loss: 4.851	Validation loss: 6.076
#
# EPOCH 86:	Training loss: 4.676	Validation loss: 6.568
#
# EPOCH 87:	Training loss: 4.893	Validation loss: 6.461
#
# EPOCH 88:	Training loss: 5.045	Validation loss: 5.241
#
# EPOCH 89:	Training loss: 4.765	Validation loss: 5.401
#
# EPOCH 90:	Training loss: 6.367	Validation loss: 6.406
#
# EPOCH 91:	Training loss: 5.270	Validation loss: 7.833
#
# EPOCH 92:	Training loss: 7.297	Validation loss: 5.959
#
# EPOCH 93:	Training loss: 5.879	Validation loss: 5.271
#
# EPOCH 94:	Training loss: 8.586	Validation loss: 7.796
#
# EPOCH 95:	Training loss: 6.244	Validation loss: 6.081
#
# EPOCH 96:	Training loss: 7.813	Validation loss: 17.118
#
# EPOCH 97:	Training loss: 6.652	Validation loss: 9.966
#
# EPOCH 98:	Training loss: 6.542	Validation loss: 7.957
#
# EPOCH 99:	Training loss: 6.190	Validation loss: 5.107
#
# EPOCH 100:	Training loss: 6.004	Validation loss: 4.894

# %%
model.eval()
with torch.no_grad():
    test_predict = model(X_test.to(device)).cpu().numpy()
    test_r2 = r_squared(y_test, test_predict)
    print(f"\nTest R^2: {test_r2:.3f}")
# Out:
# Test R^2: 0.875
